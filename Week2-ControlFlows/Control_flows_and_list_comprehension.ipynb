# %% [markdown]
# ## Week 2: Advanced control flows

# %% [markdown]
# ### TEST: PYTHON ENVIRONMENTS AND BEST PRACTICES
# Before we delve into today's topic, it's quiz time! Let's see what you learned last week. Please keep in mind that this quiz **is part of your evaluation**.
#
# <img src=".\wooclap_eval.png" width="300">
#
# Wooclap event code: BAABKAJ

# %% [markdown]
# Congrats on completing the test! Now, let's move on to today's topic.
#
# This lecture notebook based on the [Python tutorial](https://docs.python.org/3/tutorial), which you are invited to consult.
#
# #### Table of contents:
# **The notebook is organized as follows:**
#
# * **[Part 1: Recap](#21-recap-control-flows)**
#
# * **[Part 2: Pass statement](#22-pass-statement)**
#
# * **[Part 3: Match statement](#23-match-statement)**
#
# * **[Part 4: Looping techniques](#24-looping-techniques)**
#
# * **[Part 5: Conditions](#25-conditions)**
#
# * **[Part 6: List comprehension](#26-list-comprehension)**

# %% [markdown]
# ### Objectives
# - Revise basic control flow concepts
# - Get familiar with more advanced operations

# %% [markdown]
# ### 2.1 Recap: control flows
# You should already be familiar with the basic **control flow** structures:
#
# - ```if```, ```else```, ```elif```
# - ```for```
# - ```while```
#
# Here are some examples to refreshen your memory:

# %%
x = 4 # customize
if x < 0:
    x = 0
    print('Negative changed to zero')
elif x == 0:
    print('Zero')
elif x == 1:
    print('Single')
else:
    print('More')
# Out:
# More

# %%
for n in range(2, 10):
    for x in range(2, n):
        if n % x == 0:
            print(f"{n} equals {x} * {n//x}")
            break
# Out:
# 4 equals 2 * 2
# 6 equals 2 * 3
# 8 equals 2 * 4
# 9 equals 3 * 3

# %% [markdown]
# Now, let's do a little test (not evaluated) to see your level: <br>
#
# <img src="./wooclap.png" width="300">
#
# Wooclap event code: JCQOXOX

# %% [markdown]
# ### 2.2 ```Pass``` statement

# %% [markdown]
# Today, we will see more advanced control flow structure, starting with the ```pass``` statement. The pass statement does nothing. It can be used when a statement is required syntactically but the program requires no action. For example:

# %%
#while True:
 #   pass  # Busy-wait for keyboard interrupt (Ctrl+C)

# %% [markdown]
# Let's see it in an example.

# %%
age = 20

if age >= 18:
    pass

print("The program continues.")

# %% [markdown]
# The `pass` statement does not produce output and does not change `age`.
#
# #### `pass` in a function
#
# Suppose we want to create a function but have not implemented it yet:

# %%
def calculate_average(numbers):
    pass

# %% [markdown]
# Calling it:

# %%
result = calculate_average([10, 20, 30])
print(result)

# %% [markdown]
# It produces `None` because the function reaches the end without a `return` statement.
#
# Later, we can replace `pass`:

# %%
def calculate_average(numbers):
    return sum(numbers) / len(numbers)

# %% [markdown]
# Now:

# %%
print(calculate_average([10, 20, 30]))

# %% [markdown]
# To sum up: this statement can be used is as a place-holder for a function or conditional body when you are working on new code, allowing you to keep thinking at a more abstract level. The pass is silently ignored:

# %%
def initlog(*args):
    pass   # Remember to implement this!

# %%
for number in range(5):
    if number == 2:
        pass

    print(number)

# %% [markdown]
# `pass` does **not** skip `2`.
#
# #### `pass` vs `continue` vs `break`
# Look at the outputs of those cells:

# %%
# pass
for number in range(5):
    if number == 2:
        pass
    print(number)

# %%
# continue
for number in range(5):
    if number == 2:
        continue
    print(number)

# %%
# break
for number in range(5):
    if number == 2:
        break
    print(number)

# %% [markdown]
# To sum up:
#
# | Statement | Effect |
# |---|---|
# | `pass` | Do nothing |
# | `continue` | Skip the current iteration |
# | `break` | Exit the loop |

# %% [markdown]
# ### Exercises
#
# ##### Exercise 1
#
# Complete the function:

# %%
def calculate_square(number):
    pass

# %% [markdown]
# Replace `pass` with code that returns the square of `number`.
#
# Test:

# %%
print(calculate_square(5))

# %% [markdown]
# Expected output:

# %% [markdown]
# ```text
# 25
# ```

# %% [markdown]
# Solution:

# %%
def calculate_square(number):
    return number ** 2

print(calculate_square(5))

# %% [markdown]
# ##### Exercise 1
#
# Predict the output before running:

# %%
for number in range(5):
    if number == 3:
        pass

    print(number)

# %% [markdown]
# Solution:
#
# The output is:
#
# ```text
# 0
# 1
# 2
# 3
# 4
# ```
#
# `pass` does not skip the current iteration. It simply does nothing.

# %% [markdown]
# ##### Exercise 3
#
# Replace `???` with `pass`, `continue`, or `break`.
#
# A. Print every number:

# %%
for number in range(5):
    if number == 2:
        ???

    print(number)

# %% [markdown]
# B. Skip `2`:

# %%
for number in range(5):
    if number == 2:
        ???

    print(number)

# %% [markdown]
# C. Stop when reaching `2`:

# %%
for number in range(5):
    if number == 2:
        ???

    print(number)

# %%
# Solution
# Solution A
for number in range(5):
    if number == 2:
        pass
    print(number)

print("---")

# Solution B
for number in range(5):
    if number == 2:
        continue
    print(number)

print("---")

# Solution C
for number in range(5):
    if number == 2:
        break
    print(number)

# %% [markdown]
# ### 2.3 ```Match``` statement

# %% [markdown]
# Now, let's learn about ```match``` statements. A match statement takes an expression and compares its value to successive patterns given as one or more case blocks. Only the first pattern that matches gets executed and it can also extract components (sequence elements or object attributes) from the value into variables. If no case matches, none of the branches is executed. The simplest form compares a subject value against one or more literals:

# %%
def http_error(status):
    match status:
        case 400:
            return "Bad request"
        case 404:
            return "Not found"
        case 418:
            return "I'm a teapot"
        case _:
            return "Something's wrong with the internet"

# %% [markdown]
# > Note the last block: the “variable name” _ acts as a wildcard and never fails to match.

# %% [markdown]
# You can combine several literals in a single pattern using ```|``` ("or"):

# %%
def http_error(status):
    match status:
        case 401 | 403 | 404:
            return "Not allowed"

# %% [markdown]
# Now, try to execute the following example:

# %%
def day_name(day):
    match day:
        case 1:
            return "Monday"
        case 2:
            return "Tuesday"
        case 3:
            return "Wednesday"
        case 4:
            return "Thursday"
        case 5:
            return "Friday"
        case 6:
            return "Saturday"
        case 7:
            return "Sunday"
        case _:
            return "Invalid day"

# %% [markdown]
# Test:

# %%
print(day_name(1))
print(day_name(5))
print(day_name(7))

# %% [markdown]
# ### 2.4 Looping techniques
#
# Loops allow repeated execution of a block of code. You should already be familiar with the concepts from Section 1. Now, we will see more advanced looping techniques for **data structures**. Python allows iteration over many built-in data structures such as lists, tuples, strings, dictionaries, and sets.

# %% [markdown]
# ##### 2.4.1 Looping through lists

# %%
numbers = [10, 20, 30, 40]

for num in numbers:
    print(num)
# Out:
# 10
# 20
# 30
# 40

# %% [markdown]
# ##### 2.4.2 Looping through tuples

# %%
coords = (1, 2, 3)

for c in coords:
    print(c)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ##### 2.4.3 Looping through dictionaries
#
# When looping through dictionaries, the key and corresponding value can be retrieved at the same time using the `items()` method.

# %%
knights = {'gallahad': 'the pure', 'robin': 'the brave'}
for k, v in knights.items():
    print(k, v)
# Out:
# gallahad the pure
# robin the brave

# %% [markdown]
# When looping through a sequence, the position index and corresponding value can be retrieved at the same time using the `enumerate()` function.

# %%
for i, v in enumerate(['tic', 'tac', 'toe']):
    print(i, v)
# Out:
# 0 tic
# 1 tac
# 2 toe

# %% [markdown]
# To loop over two or more sequences at the same time, the entries can be paired with the `zip()` function.

# %%
questions = ['name', 'quest', 'favorite color']
answers = ['lancelot', 'the holy grail', 'blue']
for q, a in zip(questions, answers):
    print('What is your {0}?  It is {1}.'.format(q, a))
# Out:
# What is your name?  It is lancelot.
# What is your quest?  It is the holy grail.
# What is your favorite color?  It is blue.

# %% [markdown]
# To loop over a sequence in reverse, first specify the sequence in a forward direction and then call the `reversed()` function.

# %%
for i in reversed(range(1, 10, 2)):
    print(i)
# Out:
# 9
# 7
# 5
# 3
# 1

# %% [markdown]
# To loop over a sequence in sorted order, use the `sorted()` function which returns a new sorted list while leaving the source unaltered.

# %%
basket = ['apple', 'orange', 'apple', 'pear', 'orange', 'banana']
for i in sorted(basket):
    print(i)
# Out:
# apple
# apple
# banana
# orange
# orange
# pear

# %% [markdown]
# Using set() on a sequence eliminates duplicate elements. The use of `sorted()` in combination with `set()` over a sequence is an idiomatic way to loop over unique elements of the sequence in sorted order.

# %%
basket = ['apple', 'orange', 'apple', 'pear', 'orange', 'banana']
for f in sorted(set(basket)):
    print(f)
# Out:
# apple
# banana
# orange
# pear

# %% [markdown]
# It is sometimes tempting to change a list while you are looping over it; however, it is often simpler and safer to create a new list instead.

# %%
import math
raw_data = [56.2, float('NaN'), 51.7, 55.3, 52.5, float('NaN'), 47.8]
filtered_data = []
for value in raw_data:
    if not math.isnan(value):
        filtered_data.append(value)

filtered_data
# Out:
# [56.2, 51.7, 55.3, 52.5, 47.8]

# %% [markdown]
# #### Exercises
# Try solving the following:
# 1. Print only even numbers from a list
# 2. Count occurrences of letters in a string using a loop
# 3. Print all keys and values from a dictionary
# 4. Merge two lists using zip()

# %%
# Write your exercises here

# %%
# Exercise 1
nums = [1,2,3,4,5,6]
for n in nums:
    if n % 2 == 0:
        print(n)
# Exercise 2
text = "banana"
count = {}
for ch in text:
    count[ch] = count.get(ch, 0) + 1
print(count)
# Exercise 3
student = {"name": "Alice", "age": 20}
for k, v in student.items():
    print(k, v)
# Exercise 4
a = [1,2,3]
b = ["a","b","c"]

for x, y in zip(a, b):
    print(x, y)
# Out:
# 2
# 4
# 6
# {'b': 1, 'a': 3, 'n': 2}
# name Alice
# age 20
# 1 a
# 2 b
# 3 c

# %% [markdown]
# ### 2.5 Conditions

# %% [markdown]
# Conditions are one of the most important parts of programming. They allow a program to **make decisions**.
#
# Conditions are used with:
# - `if`, `elif`, and `else`
# - `while`
# - comparison operators
# - membership tests (`in`, `not in`)
# - identity tests (`is`, `is not`)
# - Boolean operators (`and`, `or`, `not`)
# - input validation and filtering
#
# A condition produces a Boolean result: `True` or `False`.

# %% [markdown]
# The conditions used in while and if statements can contain any operators, not just comparisons.
#
# The comparison operators `in` and `not in` are membership tests that determine whether a value is in (or not in) a container. The operators `is` and `is not` compare whether two objects are really the same object. All comparison operators have the same priority, which is lower than that of all numerical operators.
#
# Comparisons can be chained. For example, `a < b == c` tests whether `a` is less than `b` and moreover `b` equals `c`.
#
# Comparisons may be combined using the Boolean operators and and or, and the outcome of a comparison (or of any other Boolean expression) may be negated with not. These have lower priorities than comparison operators; between them, not has the highest priority and or the lowest, so that `A` and not `B` or `C` is equivalent to `(A and (not B))` or `C`. As always, parentheses can be used to express the desired composition.
#
# The Boolean operators and and or are so-called short-circuit operators: their arguments are evaluated from left to right, and evaluation stops as soon as the outcome is determined. For example, if `A` and `C` are true but `B` is false, `A` and `B` and `C` does not evaluate the expression `C`. When used as a general value and not as a Boolean, the return value of a short-circuit operator is the last evaluated argument.
#
# It is possible to assign the result of a comparison or other Boolean expression to a variable. For example,

# %%
string1, string2, string3 = '', 'Trondheim', 'Hammer Dance'
non_null = string1 or string2 or string3
non_null
# Out:
# 'Trondheim'

# %% [markdown]
# #### Comparison Operators
#
# | Operator | Meaning | Example |
# |---|---|---|
# | `==` | equal to | `a == b` |
# | `!=` | not equal to | `a != b` |
# | `<` | less than | `a < b` |
# | `>` | greater than | `a > b` |
# | `<=` | less than or equal to | `a <= b` |
# | `>=` | greater than or equal to | `a >= b` |
#
# **Important:** `=` assigns a value, while `==` compares two values.

# %%
a = 10
b = 20

print(a == b)
print(a != b)
print(a < b)
print(a > b)
print(a <= b)
print(a >= b)

# %% [markdown]
# #### Conditions in `if` Statements
#
# An `if` statement executes its body only when its condition is `True`.

# %%
temperature = 25

if temperature > 20:
    print("It is warm.")
else:
    print("It is cold.")

# %% [markdown]
# #### Conditions in `while` Loops
#
# The condition of a `while` loop is checked before every iteration.

# %%
number = 1

while number <= 5:
    print(number)
    number += 1

# %% [markdown]
# #### Membership Tests: `in` and `not in`
#
# `in` and `not in` test whether a value belongs to a container.
#
# They work with lists, tuples, sets, strings, dictionaries, and other containers.

# %%
fruits = ["apple", "banana", "orange"]

print("apple" in fruits)
print("pear" in fruits)
print("pear" not in fruits)

# %% [markdown]
# ### Membership tests with strings
#
# A string is a sequence of characters, so `in` can test whether a substring or character occurs in it.

# %%
text = "Python programming"

print("Python" in text)
print("Java" in text)
print("p" in text)
print("z" not in text)

# %% [markdown]
# ### Membership tests with dictionaries
#
# For dictionaries, `in` normally tests **keys**, not values.

# %%
student = {
    "name": "Alice",
    "age": 20,
    "course": "Python"
}

print("name" in student)
print("Alice" in student)
print("age" not in student)

# %% [markdown]
# #### Identity Tests: `is` and `is not`
#
# `is` and `is not` test **object identity**.
#
# They ask:
#
# > Are these two references pointing to the same object?
#
# This is different from `==`, which asks whether two objects have equal values.
#
# For example:

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print(a == b)   # Same value
print(a is b)   # Different list objects

print(a == c)
print(a is c)   # c refers to the same object as a

# %% [markdown]
# #### `==` versus `is`
#
# Use `==` when you want to compare **values**.
#
# Use `is` when you want to test **identity**.
#
# A very common use of `is` is checking for `None`:

# %%
value = None

if value is None:
    print("No value was provided.")

# %% [markdown]
# Avoid using `is` as a general replacement for `==`.
#
# Prefer:
#
# ```python
# x == 5
# ```
#
# rather than:
#
# ```python
# x is 5
# ```
#
# when comparing a value to `5`.

# %%
x = 5

print(x == 5)
print(x is 5)  # Do not use identity this way in normal programs

# %% [markdown]
# #### Chained Comparisons
#
# Python allows comparisons to be chained.
#
# For example:
#
# ```python
# a < b == c
# ```
#
# means:
#
# ```python
# (a < b) and (b == c)
# ```
#
# The middle value is shared between the comparisons.

# %%
a = 2
b = 5
c = 5

print(a < b == c)
print((a < b) and (b == c))

# %% [markdown]
# Chained comparisons are especially useful for checking whether a value lies in a range.

# %%
age = 25

if 18 <= age < 65:
    print("Age is between 18 and 64.")

# %% [markdown]
# This is usually clearer than writing:
#
# ```python
# if age >= 18 and age < 65:
# ```
#
# Both are valid.

# %%
age = 25

print(18 <= age < 65)
print(age >= 18 and age < 65)

# %% [markdown]
# #### Boolean Operators
#
# Python provides three Boolean operators:
#
# | Operator | Meaning |
# |---|---|
# | `and` | both conditions must be true |
# | `or` | at least one condition must be true |
# | `not` | reverses a Boolean result |
#
# Examples:
#
# ```python
# A and B
# A or B
# not A
# ```

# %%
A = True
B = False

print(A and B)
print(A or B)
print(not A)
print(not B)

# %% [markdown]
# ##### `and`
#
# `and` requires both expressions to be true.

# %%
age = 25
has_ticket = True

if age >= 18 and has_ticket:
    print("You may enter.")

# %% [markdown]
# ##### `or`
#
# `or` is true when at least one expression is true.

# %%
day = "Saturday"

if day == "Saturday" or day == "Sunday":
    print("It is the weekend.")

# %% [markdown]
# ##### `not`
#
# `not` reverses a Boolean expression.

# %%
logged_in = False

if not logged_in:
    print("Please log in.")

# %% [markdown]
# ### Exercises
# ##### Exercise 1
#
# Ask the user for their age and print:
# - `"Adult"` if the age is at least 18
# - `"Minor"` otherwise.

# %%
# Write your exercise here

# %%
# Solution
age = int(input("Enter your age: "))

if age >= 18:
    print("Adult")
else:
    print("Minor")

# %% [markdown]
# ##### Exercise 2
#
# Write a program that asks for a number and prints:
# - `"Positive"` if it is greater than zero
# - `"Negative"` if it is less than zero
# - `"Zero"` if it equals zero.

# %%
# Write your exercise here

# %%
# Solution
number = float(input("Enter a number: "))

if number > 0:
    print("Positive")
elif number < 0:
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# ##### Exercise 3
#
# Given:
#
# ```python
# languages = ["Python", "Java", "C++", "JavaScript"]
# ```
#
# Write conditions that check:
# 1. whether `"Python"` is in the list
# 2. whether `"Ruby"` is in the list
# 3. whether `"Ruby"` is not in the list

# %%
# Write your exercise here

languages = ["Python", "Java", "C++", "JavaScript"]

# %%
# Solution
languages = ["Python", "Java", "C++", "JavaScript"]

print("Python" in languages)
print("Ruby" in languages)
print("Ruby" not in languages)

# %% [markdown]
# ##### Exercise 4
#
# Ask the user to enter a sentence.
#
# Check whether the sentence contains the word `"Python"`.
#
# Print an appropriate message.

# %%
# Write your exercise here

# %%
# Solution
sentence = input("Enter a sentence: ")

if "Python" in sentence:
    print("The sentence contains Python.")
else:
    print("The sentence does not contain Python.")

# %% [markdown]
# ##### Exercise 5
#
# Ask the user for a number.
#
# Print `"Inside"` if the number is between 10 and 20 inclusive.
#
# Use a chained comparison.

# %%
# Write your exercise here

# %%
# Solution
number = float(input("Enter a number: "))

if 10 <= number <= 20:
    print("Inside")
else:
    print("Outside")

# %% [markdown]
# ### 2.6 List comprehension

# %% [markdown]
# List comprehensions provide a concise way to create lists. Common applications are to make new lists where each element is the result of some operations applied to each member of another sequence or iterable, or to create a subsequence of those elements that satisfy a certain condition.
#
# For example, assume we want to create a list of squares, like:

# %%
squares = []
for x in range(10):
    squares.append(x**2)
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# Note that this creates (or overwrites) a variable named x that still exists after the loop completes. We can calculate the list of squares without any side effects using one of the two following techniques:

# %%
squares = [x**2 for x in range(10)]

# %%
squares = list(map(lambda x: x**2, range(10)))

# %% [markdown]
# A list comprehension consists of brackets containing an expression followed by a `for` clause, then zero or more for `or if` clauses. The result will be a new list resulting from evaluating the expression in the context of the for and if clauses which follow it. For example, this list comp combines the elements of two lists if they are not equal:

# %%
[(x, y) for x in [1,2,3] for y in [3,1,4] if x != y]
# Out:
# [(1, 3), (1, 4), (2, 3), (2, 1), (2, 4), (3, 1), (3, 4)]

# %%
combs = []
for x in [1,2,3]:
    for y in [3,1,4]:
        if x != y:
            combs.append((x, y))

combs
# Out:
# [(1, 3), (1, 4), (2, 3), (2, 1), (2, 4), (3, 1), (3, 4)]

# %% [markdown]
# Note how the order of the `for` and `if` statements is the same in both these snippets.
#
# If the expression is a tuple (e.g. the `(x, y)` in the previous example), it must be parenthesized.

# %%
## Uncomment the lines one by one to see what happens

#vec = [-4, -2, 0, 2, 4]
# create a new list with the values doubled
#[x*2 for x in vec]
# filter the list to exclude negative numbers
#[x for x in vec if x >= 0]
# apply a function to all the elements
#[abs(x) for x in vec]
# call a method on each element
#freshfruit = ['  banana', '  loganberry ', 'passion fruit  ']
#[weapon.strip() for weapon in freshfruit]
#['banana', 'loganberry', 'passion fruit']
# create a list of 2-tuples like (number, square)
#[(x, x**2) for x in range(6)]
# the tuple must be parenthesized, otherwise an error is raised
#[x, x**2 for x in range(6)]
 
# flatten a list using a listcomp with two 'for'
vec = [[1,2,3], [4,5,6], [7,8,9]]
[num for elem in vec for num in elem]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# #### Exercises
# Create a list of squares of numbers from 1 to 20.

# %%
# Write your exercise here

# %%
# Solution

squares = [x**2 for x in range(1, 21)]

print(squares)

# %% [markdown]
# Generate a list of even numbers from 1 to 50.

# %%
# Write your exercise here

# %%
# Solution

even_numbers = [x for x in range(1, 51) if x % 2 == 0]

print(even_numbers)

# %% [markdown]
# From 1 to 50, create a list of numbers divisible by both 3 and 5.

# %%
# Write your exercise here

# %%
# Solution

numbers = [x for x in range(1, 51) if x % 3 == 0 and x % 5 == 0]

print(numbers)

# %% [markdown]
# From this list:
#
# `nums = [10, 15, 20, 25, 30, 35]`
#
# keep only numbers greater than 20.

# %%
# Write your exercise here

# %%
# Solution

nums = [10, 15, 20, 25, 30, 35]

greater_than_20 = [x for x in nums if x > 20]

print(greater_than_20)

# %% [markdown]
# Extract only vowels from the string:
#
# `text = "list comprehensions make python concise"`

# %%
# Your exercise here

# %%
# Solution
text = "list comprehensions make python concise"

vowels = [char for char in text if char in "aeiou"]

print(vowels)
